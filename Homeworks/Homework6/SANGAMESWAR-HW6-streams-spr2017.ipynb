# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('kNI4jfjC0oKhuRuVukGKhXQ2A', '48jYr5tqQx1pvokXOV6lRAWapWdjhbXuCfjcEYpWX17bKq3EjT')
auth.set_access_token('918302203911208961-Ub48HAsc8TskqIJOV2zyHEPibUrL96i', '5MnNYQI7wHWNc92OiS4VBVwbVfT6ow5x5shk0YmaHpGB8')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('twodaydata.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,
                           q = "google",
                           since = 2017-12-15,
                           #until = "2014-02-15",
                           lang = "en").items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print tweet.created_at, tweet.text
csvFile.close()


#Reference
#https://stackoverflow.com/questions/21865413/get-data-from-twitter-using-tweepy-and-store-in-csv-file
# Out:
# 2017-12-07 20:45:28 The One Deadly Pet Toy You Need to Avoid Giving Your Dog https://t.co/hUJ1AxdYPj But next time you head to the pet… https://t.co/qNDkA744cf
# 2017-12-07 20:45:28 Forrester names VMware a leader in enterprise mobility management https://t.co/lxfNAzQaor #SAAS
# 2017-12-07 20:45:28 Two Vulnerabilities Patched in OpenSSL - The OpenSSL Project announced on Thursday the availability of OpenSSL 1.0.… https://t.co/L8MHhIWuQO
# 2017-12-07 20:45:28 RT @Essence: .@ChanceTheRapper's youth charity foundation 'SocialWorks' receives a $1 million grant from Google. https://t.co/d6jGD4bJNM ht…
# 2017-12-07 20:45:28 AlphaZero needs to be put on things like fixing our politics and climate change.  https://t.co/uy9rRbKDgM
# 2017-12-07 20:45:27 RT @coll3enshanahan: If the girl in my class could get through her presentation after her nudes on Google Drive were projected to the whole…
# ...

# %%
#Reference
#http://www.geeksforgeeks.org/removing-stop-words-nltk-python/

import io
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#word_tokenize accepts a string as an input, not a file.
stop_words = set(stopwords.words('english'))
file1 = open("1days.txt")
line = file1.read()# Use this to read file content as a stream:
words = line.split()
for r in words:
    if not r in stop_words:
        appendFile = open('result.txt','a')
        appendFile.write(" "+r)
        appendFile.close()
